# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = sns.load_dataset('iris')
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# As, we predict species, so lets check the values in that
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
# now split the X and y
X = df.drop('species', axis=1)
y = df['species']

# %%
# train test split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# # knn model

# %%
# import library
from sklearn.neighbors import KNeighborsClassifier
# set parameters
model_knn = KNeighborsClassifier(n_neighbors=5)

# %%
# train the model
model_knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
# see the model score/accuracy
model_knn.score(X_test, y_test)
# Out:
# 0.98

# %% [markdown]
# Note: If we change the value of n_neighbors like, 9, 10, 13 etc, then the  model score also changed. Thats because we changed the parameters of model

# %% [markdown]
# # svm model

# %%
from sklearn.svm import SVC
# set parameters
model_svm = SVC(C= 30, kernel='rbf', gamma='auto')

# %%
# train the model
model_svm.fit(X_train, y_train)
# Out:
# SVC(C=30, gamma='auto')

# %%
# see the model score/accuracy
model_svm.score(X_test, y_test)
# Out:
# 0.98

# %% [markdown]
# Note: here also if we change the value of kernel='linear' and C like 10, 5, 12 etc, then the model score also changed. Thats because we changed the parameters of model

# %% [markdown]
# **To decide, which parameters should we choose for better model accuracy, we will use gridSearchCV**

# %% [markdown]
# # Grid search cv

# %%
# lets perform the grid search cv on svm
from sklearn.svm import SVC

model_svm = SVC(gamma='auto')
# train the model
model_svm.fit(X_train, y_train)
# Out:
# SVC(gamma='auto')

# %%
# see the model score/accuracy
model_svm.score(X_test, y_test)
# Out:
# 1.0

# %% [markdown]
# **now, perform the grid search cv on svm**

# %%
from sklearn.model_selection import GridSearchCV

# %%
# set the parametrs on which we do cross validations multiple times
cv_classifier = GridSearchCV((model_svm), {
    'C' : [1,10,20,30],
    'kernel' : ['rbf', 'linear']
}, cv=5, return_train_score=False)

# %%
# fit the X and y
cv_classifier.fit(X, y)
# Out:
# GridSearchCV(cv=5, estimator=SVC(gamma='auto'),
#              param_grid={'C': [1, 10, 20, 30], 'kernel': ['rbf', 'linear']})

# %%
# to check the results
cv_classifier.cv_results_
# Out:
# {'mean_fit_time': array([0.00372052, 0.00544305, 0.00254617, 0.00350947, 0.00496626,
#         0.00635147, 0.00603771, 0.00756993]),
#  'std_fit_time': array([0.00116873, 0.00383365, 0.00022238, 0.00038108, 0.00079849,
#         0.00188634, 0.00233803, 0.00450516]),
#  'mean_score_time': array([0.00322013, 0.00453072, 0.00213966, 0.00301056, 0.00454235,
#         0.01261663, 0.00585113, 0.00502038]),
#  'std_score_time': array([0.00090333, 0.00276055, 0.00017202, 0.0003649 , 0.00161954,
#         0.01020112, 0.00375441, 0.00183869]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 20, 20, 30, 30],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'rbf', 'linear', 'rbf', 'linear',
#                     'rbf', 'linear'],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=np.str_('?'),
#              dtype=object),
#  'params': [{'C': 1, 'kernel': 'rbf'},
#   {'C': 1, 'kernel': 'linear'},
#   {'C': 10, 'kernel': 'rbf'},
#   {'C': 10, 'kernel': 'linear'},
#   {'C': 20, 'kernel': 'rbf'},
#   {'C': 20, 'kernel': 'linear'},
#   {'C': 30, 'kernel': 'rbf'},
#   {'C': 30, 'kernel': 'linear'}],
#  'split0_test_score': array([0.96666667, 0.96666667, 0.96666667, 1.        , 0.96666667,
#         1.        , 0.96666667, 1.        ]),
#  'split1_test_score': array([1., 1., 1., 1., 1., 1., 1., 1.]),
#  'split2_test_score': array([0.96666667, 0.96666667, 0.96666667, 0.9       , 0.9       ,
#         0.9       , 0.9       , 0.9       ]),
#  'split3_test_score': array([0.96666667, 0.96666667, 0.96666667, 0.96666667, 0.96666667,
#         0.93333333, 0.93333333, 0.9       ]),
#  'split4_test_score': array([1., 1., 1., 1., 1., 1., 1., 1.]),
#  'mean_test_score': array([0.98      , 0.98      , 0.98      , 0.97333333, 0.96666667,
#         0.96666667, 0.96      , 0.96      ]),
#  'std_test_score': array([0.01632993, 0.01632993, 0.01632993, 0.03887301, 0.03651484,
#         0.0421637 , 0.03887301, 0.04898979]),
#  'rank_test_score': array([1, 1, 1, 4, 5, 6, 7, 7], dtype=int32)}

# %%
# Its not understandable, so we convert it into dataFrame

# %%
results = pd.DataFrame(cv_classifier.cv_results_)

# %%
results.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.003721      0.001169         0.003220        0.000903        1
# 1       0.005443      0.003834         0.004531        0.002761        1
# 2       0.002546      0.000222         0.002140        0.000172       10
# 3       0.003509      0.000381         0.003011        0.000365       10
# 4       0.004966      0.000798         0.004542        0.001620       20
#
#   param_kernel                         params  split0_test_score  \
# 0          rbf      {'C': 1, 'kernel': 'rbf'}           0.966667
# 1       linear   {'C': 1, 'kernel': 'linear'}           0.966667
# 2          rbf     {'C': 10, 'kernel': 'rbf'}           0.966667
# 3       linear  {'C': 10, 'kernel': 'linear'}           1.000000
# 4          rbf     {'C': 20, 'kernel': 'rbf'}           0.966667
#
#    split1_test_score  split2_test_score  split3_test_score  split4_test_score  \
# 0                1.0           0.966667           0.966667                1.0
# 1                1.0           0.966667           0.966667                1.0
# 2                1.0           0.966667           0.966667                1.0
# 3                1.0           0.900000           0.966667                1.0
# 4                1.0           0.900000           0.966667                1.0
#
#    mean_test_score  std_test_score  rank_test_score
# 0         0.980000        0.016330                1
# 1         0.980000        0.016330                1
# 2         0.980000        0.016330                1
# 3         0.973333        0.038873                4
# 4         0.966667        0.036515                5

# %% [markdown]
# here, we need to see the parametes and output score, so we extract them from whole results

# %%
# extrat parametes that we applied and output score
results[['param_C', 'param_kernel', 'mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0        1          rbf         0.980000
# 1        1       linear         0.980000
# 2       10          rbf         0.980000
# 3       10       linear         0.973333
# 4       20          rbf         0.966667
# 5       20       linear         0.966667
# 6       30          rbf         0.960000
# 7       30       linear         0.960000

# %% [markdown]
# Note: We can also apply the grid_search_cv on knn also, by creating the parameeters that we want to put as cross validations
